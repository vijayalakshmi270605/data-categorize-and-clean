# %% [markdown]
# ### ***DATA CLEANING***

# %%
import pandas as pd

# %%
File=pd.read_csv("MOBILE.csv")

# %%
File
# Out:
#     Unnamed: 0                                               Name  \
# 0            0                        Apple iPhone 15 128GB Blue
# 1            1          Apple iPhone 13 128 GB, Midnight (Black)
# 2            2   ProElite Keyboard case for Samsung Galaxy Tab...
# 3            3                 Apple iPhone 13 128 GB, Starlight
# 4            4                       Apple iPhone 15 128GB Black
# 5            5   POCO M6 5G 128 GB, 6 GB RAM, Blue, Mobile Phone
# 6            6   OnePlus Nord CE 3 Lite 5G 256 GB, 8 GB RAM, C...
# 7            7   JioDive VR Headset Immersive 360 Degree Viewi...
# 8            8   POCO M6 5G 128 GB, 6 GB RAM, Black, Mobile Ph...
# 9            9   POCO M6 5G, 4GB RAM, 64GB ROM, Orion Blue, Sm...
# 10          10   Samsung Galaxy F15 5G 128 GB, 6 GB RAM, Green...
# 11          11   G2L Down Price Car Mount Holder 360 Degree Ro...
#
#                                                 price  \
# 0   <span class="jm-heading-xxs jm-mb-xxs">₹68,490...
# ...

# %%
File.drop("Unnamed: 0",axis=1)
# Out:
#                                                  Name  \
# 0                         Apple iPhone 15 128GB Blue
# 1           Apple iPhone 13 128 GB, Midnight (Black)
# 2    ProElite Keyboard case for Samsung Galaxy Tab...
# 3                  Apple iPhone 13 128 GB, Starlight
# 4                        Apple iPhone 15 128GB Black
# 5    POCO M6 5G 128 GB, 6 GB RAM, Blue, Mobile Phone
# 6    OnePlus Nord CE 3 Lite 5G 256 GB, 8 GB RAM, C...
# 7    JioDive VR Headset Immersive 360 Degree Viewi...
# 8    POCO M6 5G 128 GB, 6 GB RAM, Black, Mobile Ph...
# 9    POCO M6 5G, 4GB RAM, 64GB ROM, Orion Blue, Sm...
# 10   Samsung Galaxy F15 5G 128 GB, 6 GB RAM, Green...
# 11   G2L Down Price Car Mount Holder 360 Degree Ro...
#
#                                                 price  \
# 0   <span class="jm-heading-xxs jm-mb-xxs">₹68,490...
# 1   <span class="jm-heading-xxs jm-mb-xxs">₹50,490...
# 2   <span class="jm-heading-xxs jm-mb-xxs">₹2,743....
# ...

# %%
File["offer"]=File["offer"].str.strip('</span><span class="jm-badge">').astype(str)

# %%
File
# Out:
#     Unnamed: 0                                               Name  \
# 0            0                        Apple iPhone 15 128GB Blue
# 1            1          Apple iPhone 13 128 GB, Midnight (Black)
# 2            2   ProElite Keyboard case for Samsung Galaxy Tab...
# 3            3                 Apple iPhone 13 128 GB, Starlight
# 4            4                       Apple iPhone 15 128GB Black
# 5            5   POCO M6 5G 128 GB, 6 GB RAM, Blue, Mobile Phone
# 6            6   OnePlus Nord CE 3 Lite 5G 256 GB, 8 GB RAM, C...
# 7            7   JioDive VR Headset Immersive 360 Degree Viewi...
# 8            8   POCO M6 5G 128 GB, 6 GB RAM, Black, Mobile Ph...
# 9            9   POCO M6 5G, 4GB RAM, 64GB ROM, Orion Blue, Sm...
# 10          10   Samsung Galaxy F15 5G 128 GB, 6 GB RAM, Green...
# 11          11   G2L Down Price Car Mount Holder 360 Degree Ro...
#
#                                                 price    offer
# ...

# %%
File["price"]=File["price"].str.strip('')

# %%
File
# Out:
#     Unnamed: 0                                               Name  \
# 0            0                        Apple iPhone 15 128GB Blue
# 1            1          Apple iPhone 13 128 GB, Midnight (Black)
# 2            2   ProElite Keyboard case for Samsung Galaxy Tab...
# 3            3                 Apple iPhone 13 128 GB, Starlight
# 4            4                       Apple iPhone 15 128GB Black
# 5            5   POCO M6 5G 128 GB, 6 GB RAM, Blue, Mobile Phone
# 6            6   OnePlus Nord CE 3 Lite 5G 256 GB, 8 GB RAM, C...
# 7            7   JioDive VR Headset Immersive 360 Degree Viewi...
# 8            8   POCO M6 5G 128 GB, 6 GB RAM, Black, Mobile Ph...
# 9            9   POCO M6 5G, 4GB RAM, 64GB ROM, Orion Blue, Sm...
# 10          10   Samsung Galaxy F15 5G 128 GB, 6 GB RAM, Green...
# 11          11   G2L Down Price Car Mount Holder 360 Degree Ro...
#
#                                                 price    offer
# ...

# %% [markdown]
# ### ***CATEGORICAL DATA***

# %%
Salary_Data=pd.DataFrame({"Salary":[10000,20000,25000,30000,45000,50000],"Range":['LOW','LOW','MID','MID','HIGH','HIGH']})

# %%
Salary_Data
# Out:
#    Salary Range
# 0   10000   LOW
# 1   20000   LOW
# 2   25000   MID
# 3   30000   MID
# 4   45000  HIGH
# 5   50000  HIGH

# %%
Code=Salary_Data.Range.map({'LOW':3,'HIGH':1,'MID':2})

# %%
Code
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    1
# 5    1
# Name: Range, dtype: int64

# %%
Code2=Salary_Data.Range.map({'LOW':'a','HIGH':'b','MID':'c'})

# %%
Code2
# Out:
# 0    a
# 1    a
# 2    c
# 3    c
# 4    b
# 5    b
# Name: Range, dtype: object

# %%
publish=pd.DataFrame(Salary_Data['Salary'],columns=['Salary'])

# %%
publish["code"]=Code

# %%
publish
# Out:
#    Salary  code
# 0   10000     3
# 1   20000     3
# 2   25000     2
# 3   30000     2
# 4   45000     1
# 5   50000     1
